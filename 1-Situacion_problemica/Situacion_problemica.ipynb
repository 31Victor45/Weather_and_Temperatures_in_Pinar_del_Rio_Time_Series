# %% [markdown]
# # Situacion problémica 😣
#
# Una vez descargado el csv con las temperaturas mínimas y máximas registradas en ese periodo de tiempo en mi ciudad natal, varias interrogantes han pasado por mi mente:
#
# 1. ¿Fue el verano de 2024 mas caluroso que el verano de 2025 ?
# 2. ¿Qué meses de cada año fueron los mas fríos o calurosos ?¿Fueron estos realmente superiores al resto de meses del año?
# 3. ¿Pudieramos llegar a predecir la temperatura promedio de un día determinado ?
#
# <center><img src = "img/img1.png" whidth = 300 height = 320></center>

# %% [markdown]
# Pues para responder a las interrogantes anteriores y mas he decidido hacer este proyecto, el cual es mi primer proyecto de series temporales el cual estoy seguro que me ayudará a seguir aprendiendo y será el puente a desafíos mas complejos en el futuro.
#
# Espero que puedas apreciar mi esfuerzo y ahora si acompañame a la siguiente fase que será la limpieza de los datos.
