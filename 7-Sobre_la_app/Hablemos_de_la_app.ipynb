# %% [markdown]
# # **Hablemos de la aplicación realizada 👨‍🏫**
#
# Quiero empezar comentando el hecho de que este es mi primer proyecto realcionado al tema de series temporales. Quise tocar un tema cercano como lo es las temperaturas mínimas y máximas de mi provincia Pinar del Río. La idea de poder predecirlas me resultaba muy interesante
#
# Como vemos en la siguiente imagen, partíamos de 2 series no estaciorarias lo cual pudimos comprobar gracias a los gráficos ACF/PACF (estos analisis tienen su propio notebook, consultalos en caso de no entender algo)
#
# <center><img src = "img/img2.png" width = 500 height = 400></center>
#
# Y gracias a estos y a las pruebas realizadas posteriormente llegamos a la conclusión de que estas series debían aplicarseles trasnformaciones (Box-Cox y Diferenciación [d =1]) y seguidamente contruimos un modelo VARIMA el cual tambien fue validado gracias a pruebas realizadas, resultando en la app que seguro ya pudistes probar (todo este proceso está documentado en el proyecto, sientete libre de consultarlo en caso de no entender algo)
#
# #### **Espero que el proyecto te haya gustado y gracias por verlo**
